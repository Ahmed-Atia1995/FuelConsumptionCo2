# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/FuelConsumptionCo2.csv')
data.head(7)
# Out:
#    MODELYEAR Brands VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0       2014  ACURA      COMPACT         2.0          4          AS5        Z
# 1       2014  ACURA      COMPACT         2.4          4           M6        Z
# 2       2014  ACURA      COMPACT         1.5          4          AV7        Z
# 3       2014  ACURA    SUV_SMALL         3.5          6          AS6        Z
# 4       2014  ACURA    SUV_SMALL         3.5          6          AS6        Z
# 5       2014  ACURA     MID_SIZE         3.5          6          AS6        Z
# 6       2014  ACURA     MID_SIZE         3.5          6          AS6        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                   9.9                  6.7                   8.5
# 1                  11.2                  7.7                   9.6
# 2                   6.0                  5.8                   5.9
# 3                  12.7                  9.1                  11.1
# ...

# %% [markdown]
#  FUELCONSUMPTION_COMB_MPG = MPG stands for miles per gallon
#
#  FUELCONSUMPTION_HWY = HWY stands for highway
#
#  TRANSMISSION= gear box

# %%
data.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
print(data.info())
print('data length is:',len(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   Brands                    1067 non-null   object
#  2   VEHICLECLASS              1067 non-null   object
#  3   ENGINESIZE                1067 non-null   float64
#  4   CYLINDERS                 1067 non-null   int64
#  5   TRANSMISSION              1067 non-null   object
#  6   FUELTYPE                  1067 non-null   object
#  7   FUELCONSUMPTION_CITY      1067 non-null   float64
#  8   FUELCONSUMPTION_HWY       1067 non-null   float64
#  9   FUELCONSUMPTION_COMB      1067 non-null   float64
#  10  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  11  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 100.2+ KB
# None
# data length is: 1067

# %% [markdown]
# there are no null values

# %%
print('number of Brands = ',data['Brands'].value_counts().count())
#data['Brands'].value_counts().plot(kind='bar', figsize=(14, 6))
plt.xlabel('Brand')
plt.ylabel('Number of cars')
counts = data['Brands'].value_counts()
ax = counts.plot(kind='bar', figsize=(14, 6))
# Add labels to the bars
for i, count in enumerate(counts):
    ax.text(i, count, str(count), ha='center', va='bottom')
plt.show()
# Out:
# number of Brands =  39

# %%
print('number of ENGINESIZE = ',data['ENGINESIZE'].value_counts().count())
print('The engine size range is between',data['ENGINESIZE'].min(),'to',data['ENGINESIZE'].max())
counts=data['ENGINESIZE'].value_counts()
ax = counts.plot(kind='bar', figsize=(14, 6))
# Add labels to the bars
plt.xlabel('ENGINESIZE')
plt.ylabel('Counts')
for i, count in enumerate(counts):
    ax.text(i, count, str(count), ha='center', va='bottom')
plt.show()
# Out:
# number of ENGINESIZE =  45
# The engine size range is between 1.0 to 8.4

# %%
print('number of transmmisiion gear box = ',data['TRANSMISSION'].value_counts().count())
counts=data['TRANSMISSION'].value_counts()
ax = counts.plot(kind='bar', figsize=(14, 6))
# Add labels to the bars
plt.xlabel('TRANSMISSION')
plt.ylabel('Counts')
for i, count in enumerate(counts):
    ax.text(i, count, str(count), ha='center', va='bottom')
plt.show()
# Out:
# number of transmmisiion gear box =  22

# %% [markdown]
# there are 22 types of transmission (gear box)

# %%
print('number of vehicle classes = ',data['VEHICLECLASS'].value_counts().count())
plt.figure(figsize=(14,6))
counts=data['VEHICLECLASS'].value_counts()
ax = sns.countplot(data=data, x='VEHICLECLASS')
# Rotate the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')
plt.show()
# Out:
# number of vehicle classes =  16

# %%
print('number of fuel types = ',data['FUELTYPE'].value_counts().count())
counts=data['FUELTYPE'].value_counts()
plt.pie(counts,autopct='%1.1f%%',labels=data['FUELTYPE'].value_counts().index)
plt .show()
# Out:
# number of fuel types =  4

# %%
print('number of VEHICLECLASS = ',data['VEHICLECLASS'].value_counts().count())
plt.figure(figsize=(14,6))
counts=data['VEHICLECLASS'].value_counts()

ax = sns.countplot(data=data, x='VEHICLECLASS',width=.8)

# Rotate the x-axis tick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')
# Out:
# number of VEHICLECLASS =  16

# %%
data.head(7)
# Out:
#    MODELYEAR Brands VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0       2014  ACURA      COMPACT         2.0          4          AS5        Z
# 1       2014  ACURA      COMPACT         2.4          4           M6        Z
# 2       2014  ACURA      COMPACT         1.5          4          AV7        Z
# 3       2014  ACURA    SUV_SMALL         3.5          6          AS6        Z
# 4       2014  ACURA    SUV_SMALL         3.5          6          AS6        Z
# 5       2014  ACURA     MID_SIZE         3.5          6          AS6        Z
# 6       2014  ACURA     MID_SIZE         3.5          6          AS6        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                   9.9                  6.7                   8.5
# 1                  11.2                  7.7                   9.6
# 2                   6.0                  5.8                   5.9
# 3                  12.7                  9.1                  11.1
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')

# Set the plot title
plt.title('Correlation Matrix')

# Display the plot
plt.show()
# Out:
# <ipython-input-1346-1a15408c9d8f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm')

# %%
plt.scatter(data['ENGINESIZE'],data['CYLINDERS'])
plt.xlabel('ENGIN ESIZE')
plt.ylabel('NUMBER OF CYLINDERS')
plt.show()

# %% [markdown]
# As number of cylinder increase engine size will be increse

# %%
plt.scatter(data['ENGINESIZE'],data['CO2EMISSIONS'])
plt.xlabel('ENGIN ESIZE')
plt.ylabel('CO2EMISSIONS')
plt.show()

# %% [markdown]
# when the engine size increse the co2 emission increase

# %%
plt.scatter(data['CYLINDERS'],data['CO2EMISSIONS'])
plt.xlabel('Number of cylinders')
plt.ylabel('CO2EMISSIONS')
plt.show()

# %% [markdown]
# when number of cylinders increse the co2 emission increase

# %%
plt.scatter(data['ENGINESIZE'],data['FUELCONSUMPTION_COMB_MPG'])
plt.xlabel('ENGIN ESIZE')
plt.ylabel('FUELCONSUMPTION_COMB_MPG')
plt.show()

# %% [markdown]
# When the engine size increse MPG decrese

# %%
plt.scatter(data['CYLINDERS'],data['FUELCONSUMPTION_COMB_MPG'])
plt.xlabel('NUMBER OF CYLINDERS')
plt.ylabel('FUELCONSUMPTION_COMB_MPG')
plt.show()

# %% [markdown]
# When the number of cylinders increse MPG decrese

# %%
data.plot(kind='scatter', x='FUELCONSUMPTION_CITY', y='CO2EMISSIONS')
data.plot(kind='scatter', x='FUELCONSUMPTION_HWY', y='CO2EMISSIONS')
plt.show()

# %%
data.plot(kind='scatter', x='FUELCONSUMPTION_COMB', y='CO2EMISSIONS')
plt.show()

# %% [markdown]
# when (fuelconsumption in both high way or in city increse the Co2 emission will be increase

# %%
data.plot(kind='scatter', x='FUELCONSUMPTION_COMB_MPG', y='CO2EMISSIONS')
plt.show()

# %% [markdown]
# when MPG increse the co2 emission will be decresed

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x="Brands", y='CO2EMISSIONS', data=data)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# MAZDA ,MINI,SCION  have the least co2 emission
#
# LAMBORGINY have the most CO2 emission

# %%
data['Brands'].unique()
# Out:
# array(['ACURA', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW', 'BUICK',
#        'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT', 'FORD',
#        'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP', 'KIA',
#        'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO'], dtype=object)

# %%
data[['ENGINESIZE','CYLINDERS']][data['Brands']=='LAMBORGHINI']
# Out:
#      ENGINESIZE  CYLINDERS
# 633         6.5         12
# 634         5.2         10
# 635         5.2         10

# %%
data[['ENGINESIZE','CYLINDERS']][data['Brands']=='MAZDA']
# Out:
#      ENGINESIZE  CYLINDERS
# 694         2.0          4
# 695         2.0          4
# 696         2.5          4
# 697         2.0          4
# 698         2.5          4
# 699         3.7          6
# 700         3.7          6
# 701         1.5          4
# 702         1.5          4
# 703         2.0          4
# 704         2.0          4
# 705         2.5          4
# 706         2.5          4
# 707         2.0          4
# 708         2.0          4
# 709         2.0          4
# 710         2.5          4
# 711         2.5          4
# 712         2.0          4
# 713         2.5          4
# 714         2.5          4
# 715         2.5          4
# 716         2.5          4
# 717         2.5          4
# 718         2.0          4
# 719         2.0          4
# 720         2.0          4

# %% [markdown]
# LAMBORGINI have the most co2 EMISSION as it have the largest number of cylinders and  the highest engine size
#
# MAZDA is visaverse of LAMBORGINI

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x="TRANSMISSION", y='CO2EMISSIONS', data=data)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# AV7 gear box have the least Co2 emission
#
# A4 have the highest co2 emissions

# %%
data['TRANSMISSION'].unique()
# Out:
# array(['AS5', 'M6', 'AV7', 'AS6', 'A6', 'AM7', 'AV8', 'AS8', 'A7', 'A8',
#        'M7', 'A4', 'M5', 'AV', 'A5', 'AM6', 'AS7', 'A9', 'AS9', 'AV6',
#        'AS4', 'AM5'], dtype=object)

# %%
data[['FUELCONSUMPTION_COMB','ENGINESIZE','CYLINDERS']][data['TRANSMISSION']=='AV7']
# Out:
#      FUELCONSUMPTION_COMB  ENGINESIZE  CYLINDERS
# 2                     5.9         1.5          4
# 482                   8.1         2.4          4
# 489                   7.2         1.8          4
# 494                   6.3         1.5          4
# 973                   7.3         1.8          4

# %%
data[['FUELCONSUMPTION_COMB','ENGINESIZE','CYLINDERS']][data['TRANSMISSION']=='A4']
# Out:
#       FUELCONSUMPTION_COMB  ENGINESIZE  CYLINDERS
# 210                   15.1         4.3          6
# 211                   15.9         5.3          8
# 212                   20.9         5.3          8
# 213                   16.5         5.3          8
# 214                   21.5         5.3          8
# 215                   16.5         5.3          8
# 216                   21.5         5.3          8
# 217                   16.5         5.3          8
# 218                   22.6         5.3          8
# 219                   16.5         5.3          8
# 220                   21.5         5.3          8
# 221                   16.5         5.3          8
# 222                   22.6         5.3          8
# 275                   10.1         2.4          4
# 279                    9.8         2.4          4
# 293                    9.8         2.4          4
# 328                   11.1         2.4          4
# 343                   16.2         4.6          8
# ...

# %% [markdown]
# AV7 have the most co2 EMISSION as it have the largest number of cylinders and the highest engine size
#
# A4 is visaverse of LAMBORGINI

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x="VEHICLECLASS", y='CO2EMISSIONS', data=data)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# van passenger class have the most co2 emission
#
# Compact have the least co2 emissions

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x="FUELTYPE", y='CO2EMISSIONS', data=data)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# X = regular gasoline.
# Z = premium gasoline.
# D = diesel.
# E = ethanol

# %%
data[['ENGINESIZE','CYLINDERS']][data['FUELTYPE']=='D'].value_counts()
# Out:
# ENGINESIZE  CYLINDERS
# 3.0         6            14
# 2.0         4            11
# 2.1         4             2
# dtype: int64

# %%
data[['ENGINESIZE','CYLINDERS']][data['FUELTYPE']=='E'].value_counts()
# Out:
# ENGINESIZE  CYLINDERS
# 5.3         8            24
# 3.6         6            23
# 5.0         8            10
# 3.5         6             6
# 2.0         4             5
# 3.7         6             4
# 4.3         6             4
# 5.4         8             4
# 6.0         8             4
# 6.2         8             4
# 3.0         6             2
# 4.6         8             2
# dtype: int64

# %% [markdown]
# # Model

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
data['TRANSMISSION'] = label_encoder.fit_transform(data['TRANSMISSION'])
data['FUELTYPE']=label_encoder.fit_transform(data['FUELTYPE'])
data['VEHICLECLASS']=label_encoder.fit_transform(data['VEHICLECLASS'])

# %%
data.head()
# Out:
#    MODELYEAR Brands  VEHICLECLASS  ENGINESIZE  CYLINDERS  TRANSMISSION  \
# 0       2014  ACURA             0         2.0          4            10
# 1       2014  ACURA             0         2.4          4            20
# 2       2014  ACURA             0         1.5          4            17
# 3       2014  ACURA            11         3.5          6            11
# 4       2014  ACURA            11         3.5          6            11
#
#    FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0         3                   9.9                  6.7                   8.5
# 1         3                  11.2                  7.7                   9.6
# 2         3                   6.0                  5.8                   5.9
# 3         3                  12.7                  9.1                  11.1
# 4         3                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# ...

# %%
#x=data[['ENGINESIZE','VEHICLECLASS','CYLINDERS','TRANSMISSION','FUELTYPE','FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG']].values
#x=data[['FUELCONSUMPTION_CITY','FUELTYPE','FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG']].values
x=data[['CYLINDERS','FUELTYPE','FUELCONSUMPTION_COMB']].values.reshape(1, -1)
#x=data[['CYLINDERS','VEHICLECLASS','FUELTYPE','FUELCONSUMPTION_COMB']].values
#x=data[['CYLINDERS','FUELTYPE']].values
#x=data[['ENGINESIZE']].values
y=data['CO2EMISSIONS'].values
#x=data[['CYLINDERS','FUELTYPE','FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG']].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data[['CYLINDERS','FUELTYPE','FUELCONSUMPTION_COMB']].values,y,random_state=12,test_size=0.3)
model=LinearRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from mlxtend.evaluate import bias_variance_decomp
avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(model, x_train, y_train, x_test, y_test, loss='mse', num_rounds=4, random_seed=43)
print(f'Average Expected Loss: {round(avg_expected_loss, 4)}')
print(f'Average Bias: {round(avg_bias, 4)}')
print(f'Average Variance: {round(avg_var, 4)}')
# Out:
# Average Expected Loss: 464.5599
# Average Bias: 461.6233
# Average Variance: 2.9367

# %%
plt.figure(figsize=(20,4))
plt.plot(y_predict, label='Predicted',linewidth=2)
plt.plot(y_test,label='actual',linewidth=2)

plt.legend()
plt.show()

# %% [markdown]
# -bais is high with linear regression which is indicate under fitting model so we will try another model which will be more complex

# %%
from sklearn.preprocessing import PolynomialFeatures
for i in range(1,7):

  poly_reg = PolynomialFeatures(degree =i)

  x_poly_train = poly_reg.fit_transform(x_train)
  x_poly_test = poly_reg.transform(x_test)

  PL_model =LinearRegression()
  PL_model.fit(x_poly_train,y_train)

  y_pred = PL_model.predict(x_poly_test)


  avg_Error, avg_bais, avg_var = bias_variance_decomp(PL_model, x_poly_train,y_train, x_poly_test, y_test, loss='mse', random_seed = 1)

  print(' * '*10, 'Degree = ',i,' * '*10)
  print('Error MSE = ',avg_Error )
  print('Error bais = ',avg_bais )
  print('Error variance = ',avg_var )
# Out:
#  *  *  *  *  *  *  *  *  *  *  Degree =  1  *  *  *  *  *  *  *  *  *  *
# Error MSE =  467.4360910918175
# Error bais =  462.3774700090055
# Error variance =  5.058621082812097
#  *  *  *  *  *  *  *  *  *  *  Degree =  2  *  *  *  *  *  *  *  *  *  *
# Error MSE =  130.64223225394196
# Error bais =  124.14595808932188
# Error variance =  6.496274164619998
#  *  *  *  *  *  *  *  *  *  *  Degree =  3  *  *  *  *  *  *  *  *  *  *
# Error MSE =  6.873837020158753
# Error bais =  6.1152043631780035
# Error variance =  0.7586326569807815
#  *  *  *  *  *  *  *  *  *  *  Degree =  4  *  *  *  *  *  *  *  *  *  *
# Error MSE =  0.11805056723524956
# Error bais =  0.08587017149716973
# Error variance =  0.032180395738084976
#  *  *  *  *  *  *  *  *  *  *  Degree =  5  *  *  *  *  *  *  *  *  *  *
# Error MSE =  12.389837507513507
# Error bais =  0.2945963959806044
# Error variance =  12.095241111532903
#  *  *  *  *  *  *  *  *  *  *  Degree =  6  *  *  *  *  *  *  *  *  *  *
# ...

# %% [markdown]
# * x=data['CYLINDERS','FUELTYPE','FUELCONSUMPTION_COMB']
#
# Degree =  4
#
# Error MSE =  0.11805056723524956
#
# Error bais =  0.08587017149716973
#
# Error variance =  0.032180395738084976
#
# * x=data['CYLINDERS','VEHICLECLASS','FUELTYPE','FUELCONSUMPTION_COMB']
#
# Degree =  4
#
# Error MSE =  0.227621624986308
#
# Error bais =  0.11600665353738082
#
# Error variance =  0.11161497144892993
# * x=data['CYLINDERS','FUELTYPE','FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG']
#
#   Degree =  3
#
# Error MSE =  4.51293383752709
#
# Error bais =  3.592443757411784
#
# Error variance =  0.9204900801152847

# %%
  poly_reg = PolynomialFeatures(degree =4)

  x_poly_train = poly_reg.fit_transform(x_train)
  x_poly_test = poly_reg.fit_transform(x_test)

  PL_model =LinearRegression()
  PL_model.fit(x_poly_train,y_train)

  y_pred = PL_model.predict(x_poly_test)
  avg_Error, avg_bais, avg_var = bias_variance_decomp(PL_model, x_poly_train,y_train, x_poly_test, y_test, loss='mse', random_seed = 1)

  print(' * '*10, 'Degree = ',4,' * '*10)
  print('Error MSE = ',avg_Error )
  print('Error bais = ',avg_bais )
  print('Error variance = ',avg_var )
# Out:
#  *  *  *  *  *  *  *  *  *  *  Degree =  4  *  *  *  *  *  *  *  *  *  *
# Error MSE =  0.11805056723524956
# Error bais =  0.08587017149716973
# Error variance =  0.032180395738084976

# %%
plt.figure(figsize=(20,6))
plt.plot(y_pred, label='Predicted',linewidth=2)
plt.plot(y_test,label='actual',linewidth=2)

plt.legend()
plt.show()
